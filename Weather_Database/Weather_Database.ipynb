# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 747

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | juwana
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | shingu
# Processing Record 7 of Set 1 | norman wells
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | rosarito
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | faanui
# Processing Record 12 of Set 1 | petropavlovka
# Processing Record 13 of Set 1 | santo domingo
# Processing Record 14 of Set 1 | vila velha
# Processing Record 15 of Set 1 | vestmanna
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | the valley
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | venice
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | kasane
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | puerto madryn
# Processing Record 28 of Set 1 | havre-saint-pierre
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 1 | ostersund
# Processing Record 34 of Set 1 | teya
# Processing Record 35 of Set 1 | ahipara
# Processing Record 36 of Set 1 | pastavy
# Processing Record 37 of Set 1 | port hedland
# Processing Record 38 of Set 1 | pudozh
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | lazaro cardenas
# Processing Record 42 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | irun
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | savalou
# Processing Record 49 of Set 1 | hasaki
# Processing Record 50 of Set 1 | salinopolis
# Processing Record 1 of Set 2 | kinablangan
# Processing Record 2 of Set 2 | cherskiy
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | mokhsogollokh
# Processing Record 5 of Set 2 | hobyo
# Processing Record 6 of Set 2 | pisco
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | caravelas
# Processing Record 11 of Set 2 | labuhan
# Processing Record 12 of Set 2 | ponta delgada
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | meulaboh
# Processing Record 16 of Set 2 | rawson
# Processing Record 17 of Set 2 | poum
# Processing Record 18 of Set 2 | hof
# Processing Record 19 of Set 2 | ulladulla
# Processing Record 20 of Set 2 | huarmey
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | merauke
# Processing Record 23 of Set 2 | oulu
# Processing Record 24 of Set 2 | beloha
# Processing Record 25 of Set 2 | komsomolskiy
# Processing Record 26 of Set 2 | guaruja
# Processing Record 27 of Set 2 | kalmunai
# Processing Record 28 of Set 2 | ahuimanu
# Processing Record 29 of Set 2 | bilibino
# Processing Record 30 of Set 2 | marfino
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | paamiut
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | san antero
# Processing Record 36 of Set 2 | whitehorse
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | gushikawa
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | tshela
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 2 | atar
# Processing Record 46 of Set 2 | maragogi
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | dakar
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | cape town
# Processing Record 1 of Set 3 | yaring
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | nanortalik
# Processing Record 4 of Set 3 | rio piracicaba
# Processing Record 5 of Set 3 | hammerfest
# Processing Record 6 of Set 3 | olafsvik
# Processing Record 7 of Set 3 | bocas del toro
# Processing Record 8 of Set 3 | gazni
# City not found. Skipping...
# Processing Record 9 of Set 3 | sosnovo-ozerskoye
# Processing Record 10 of Set 3 | yurga
# Processing Record 11 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 12 of Set 3 | westport
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | jamestown
# Processing Record 15 of Set 3 | vardo
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | leningradskiy
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | conroe
# Processing Record 20 of Set 3 | suntar
# Processing Record 21 of Set 3 | vilyuysk
# Processing Record 22 of Set 3 | bathsheba
# Processing Record 23 of Set 3 | high level
# Processing Record 24 of Set 3 | north platte
# Processing Record 25 of Set 3 | laguna
# Processing Record 26 of Set 3 | chuy
# Processing Record 27 of Set 3 | beyneu
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | tunghsiao
# City not found. Skipping...
# Processing Record 30 of Set 3 | new norfolk
# Processing Record 31 of Set 3 | biltine
# Processing Record 32 of Set 3 | saint anthony
# Processing Record 33 of Set 3 | clyde river
# Processing Record 34 of Set 3 | kaputa
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | katsuura
# Processing Record 38 of Set 3 | birin
# Processing Record 39 of Set 3 | ko samui
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | torbay
# Processing Record 42 of Set 3 | nam tha
# City not found. Skipping...
# Processing Record 43 of Set 3 | isangel
# Processing Record 44 of Set 3 | constitucion
# Processing Record 45 of Set 3 | golyshmanovo
# Processing Record 46 of Set 3 | faya
# Processing Record 47 of Set 3 | berlevag
# Processing Record 48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | esperance
# Processing Record 50 of Set 3 | san cristobal
# Processing Record 1 of Set 4 | sereflikochisar
# Processing Record 2 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 3 of Set 4 | vostok
# Processing Record 4 of Set 4 | charters towers
# Processing Record 5 of Set 4 | vao
# Processing Record 6 of Set 4 | hobart
# Processing Record 7 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 4 | uige
# Processing Record 9 of Set 4 | saskylakh
# Processing Record 10 of Set 4 | polis
# Processing Record 11 of Set 4 | severo-kurilsk
# Processing Record 12 of Set 4 | ayan
# Processing Record 13 of Set 4 | algeciras
# Processing Record 14 of Set 4 | srednekolymsk
# Processing Record 15 of Set 4 | luderitz
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 19 of Set 4 | tapejara
# Processing Record 20 of Set 4 | ilulissat
# Processing Record 21 of Set 4 | miles city
# Processing Record 22 of Set 4 | starokostyantyniv
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | contai
# Processing Record 25 of Set 4 | airai
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | road town
# Processing Record 28 of Set 4 | olinda
# Processing Record 29 of Set 4 | mount isa
# Processing Record 30 of Set 4 | northam
# Processing Record 31 of Set 4 | los llanos de aridane
# Processing Record 32 of Set 4 | glens falls
# Processing Record 33 of Set 4 | broome
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | awjilah
# Processing Record 36 of Set 4 | mbandaka
# Processing Record 37 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 4 | nome
# Processing Record 39 of Set 4 | aquiraz
# Processing Record 40 of Set 4 | kingman
# Processing Record 41 of Set 4 | kalach-na-donu
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | bethel
# Processing Record 44 of Set 4 | chirongui
# Processing Record 45 of Set 4 | wanning
# Processing Record 46 of Set 4 | coihaique
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | sechura
# Processing Record 49 of Set 4 | karratha
# Processing Record 50 of Set 4 | dikson
# Processing Record 1 of Set 5 | puerto ayora
# Processing Record 2 of Set 5 | imbituba
# Processing Record 3 of Set 5 | pecos
# Processing Record 4 of Set 5 | necochea
# Processing Record 5 of Set 5 | koumac
# Processing Record 6 of Set 5 | mendi
# Processing Record 7 of Set 5 | saint george
# Processing Record 8 of Set 5 | tilichiki
# Processing Record 9 of Set 5 | muzhi
# Processing Record 10 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 11 of Set 5 | kavieng
# Processing Record 12 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 5 | georgetown
# Processing Record 14 of Set 5 | kondinskoye
# Processing Record 15 of Set 5 | adana
# Processing Record 16 of Set 5 | kodiak
# Processing Record 17 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 5 | nyandoma
# Processing Record 19 of Set 5 | mezen
# Processing Record 20 of Set 5 | tiksi
# Processing Record 21 of Set 5 | bonavista
# Processing Record 22 of Set 5 | salantai
# Processing Record 23 of Set 5 | klaksvik
# Processing Record 24 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 5 | port pirie
# Processing Record 26 of Set 5 | cidreira
# Processing Record 27 of Set 5 | kesinga
# Processing Record 28 of Set 5 | kankon
# Processing Record 29 of Set 5 | marsh harbour
# Processing Record 30 of Set 5 | manavgat
# Processing Record 31 of Set 5 | mehamn
# Processing Record 32 of Set 5 | kahului
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | floro
# Processing Record 35 of Set 5 | carnarvon
# Processing Record 36 of Set 5 | chokurdakh
# Processing Record 37 of Set 5 | vuktyl
# Processing Record 38 of Set 5 | lavrentiya
# Processing Record 39 of Set 5 | constantine
# Processing Record 40 of Set 5 | pacific grove
# Processing Record 41 of Set 5 | coos bay
# Processing Record 42 of Set 5 | vanderhoof
# Processing Record 43 of Set 5 | denpasar
# Processing Record 44 of Set 5 | mukono
# Processing Record 45 of Set 5 | shache
# Processing Record 46 of Set 5 | atherton
# Processing Record 47 of Set 5 | saint-pierre
# Processing Record 48 of Set 5 | aykhal
# Processing Record 49 of Set 5 | bahia honda
# Processing Record 50 of Set 5 | kruisfontein
# Processing Record 1 of Set 6 | udachnyy
# Processing Record 2 of Set 6 | grindavik
# Processing Record 3 of Set 6 | misawa
# Processing Record 4 of Set 6 | burica
# City not found. Skipping...
# Processing Record 5 of Set 6 | lanigan
# Processing Record 6 of Set 6 | padang
# Processing Record 7 of Set 6 | nalut
# Processing Record 8 of Set 6 | dawson
# Processing Record 9 of Set 6 | xianyang
# Processing Record 10 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 6 | puerto ayacucho
# Processing Record 12 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 6 | port hardy
# Processing Record 14 of Set 6 | omboue
# Processing Record 15 of Set 6 | mayumba
# Processing Record 16 of Set 6 | mahajanga
# Processing Record 17 of Set 6 | pangnirtung
# Processing Record 18 of Set 6 | luanda
# Processing Record 19 of Set 6 | carutapera
# Processing Record 20 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 6 | tianpeng
# Processing Record 22 of Set 6 | kirovsk
# Processing Record 23 of Set 6 | srivardhan
# Processing Record 24 of Set 6 | glasgow
# Processing Record 25 of Set 6 | taybad
# Processing Record 26 of Set 6 | ivanivka
# Processing Record 27 of Set 6 | surin
# Processing Record 28 of Set 6 | oranjemund
# Processing Record 29 of Set 6 | bulgan
# Processing Record 30 of Set 6 | lata
# Processing Record 31 of Set 6 | esil
# Processing Record 32 of Set 6 | bud
# Processing Record 33 of Set 6 | ialibu
# Processing Record 34 of Set 6 | roma
# Processing Record 35 of Set 6 | serdobsk
# Processing Record 36 of Set 6 | vila do maio
# Processing Record 37 of Set 6 | nemuro
# Processing Record 38 of Set 6 | taoudenni
# Processing Record 39 of Set 6 | yulara
# Processing Record 40 of Set 6 | alpinopolis
# Processing Record 41 of Set 6 | nador
# Processing Record 42 of Set 6 | narsaq
# Processing Record 43 of Set 6 | kirakira
# Processing Record 44 of Set 6 | imeni poliny osipenko
# Processing Record 45 of Set 6 | buala
# Processing Record 46 of Set 6 | payson
# Processing Record 47 of Set 6 | nouakchott
# Processing Record 48 of Set 6 | hede
# Processing Record 49 of Set 6 | salinas
# Processing Record 50 of Set 6 | a
# City not found. Skipping...
# Processing Record 1 of Set 7 | sosnovskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | lebu
# Processing Record 3 of Set 7 | okhotsk
# Processing Record 4 of Set 7 | mastic beach
# Processing Record 5 of Set 7 | mayo
# Processing Record 6 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 7 of Set 7 | cheney
# Processing Record 8 of Set 7 | camacha
# Processing Record 9 of Set 7 | buta
# Processing Record 10 of Set 7 | tura
# Processing Record 11 of Set 7 | haicheng
# Processing Record 12 of Set 7 | taiyuan
# Processing Record 13 of Set 7 | alindao
# Processing Record 14 of Set 7 | rio grande da serra
# Processing Record 15 of Set 7 | juegang
# Processing Record 16 of Set 7 | brazzaville
# Processing Record 17 of Set 7 | saint-georges
# Processing Record 18 of Set 7 | hambantota
# Processing Record 19 of Set 7 | banda aceh
# Processing Record 20 of Set 7 | praia da vitoria
# Processing Record 21 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 7 | victoria
# Processing Record 23 of Set 7 | soyo
# Processing Record 24 of Set 7 | talnakh
# Processing Record 25 of Set 7 | fort nelson
# Processing Record 26 of Set 7 | havelock
# Processing Record 27 of Set 7 | bardiyah
# Processing Record 28 of Set 7 | zemio
# Processing Record 29 of Set 7 | jacobina
# Processing Record 30 of Set 7 | bonfim
# Processing Record 31 of Set 7 | mehriz
# Processing Record 32 of Set 7 | boende
# Processing Record 33 of Set 7 | kaznejov
# Processing Record 34 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 35 of Set 7 | bahia blanca
# Processing Record 36 of Set 7 | skibbereen
# Processing Record 37 of Set 7 | sitka
# Processing Record 38 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 7 | otradnoye
# Processing Record 40 of Set 7 | ridgecrest
# Processing Record 41 of Set 7 | tam ky
# Processing Record 42 of Set 7 | deming
# Processing Record 43 of Set 7 | lompoc
# Processing Record 44 of Set 7 | sitrah
# Processing Record 45 of Set 7 | maloy
# Processing Record 46 of Set 7 | yurimaguas
# Processing Record 47 of Set 7 | tashla
# Processing Record 48 of Set 7 | raghunathpur
# Processing Record 49 of Set 7 | tuatapere
# Processing Record 50 of Set 7 | namibe
# Processing Record 1 of Set 8 | bende
# Processing Record 2 of Set 8 | anadyr
# Processing Record 3 of Set 8 | lagoa
# Processing Record 4 of Set 8 | san juan
# Processing Record 5 of Set 8 | brigantine
# Processing Record 6 of Set 8 | garissa
# Processing Record 7 of Set 8 | yar-sale
# Processing Record 8 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 8 | riyadh
# Processing Record 10 of Set 8 | mitu
# Processing Record 11 of Set 8 | alexandria
# Processing Record 12 of Set 8 | aseri
# Processing Record 13 of Set 8 | anuradhapura
# Processing Record 14 of Set 8 | souillac
# Processing Record 15 of Set 8 | ossora
# Processing Record 16 of Set 8 | kaitangata
# Processing Record 17 of Set 8 | praya
# Processing Record 18 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 19 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 20 of Set 8 | najran
# Processing Record 21 of Set 8 | awbari
# Processing Record 22 of Set 8 | nizwa
# Processing Record 23 of Set 8 | gat
# Processing Record 24 of Set 8 | damietta
# Processing Record 25 of Set 8 | katobu
# Processing Record 26 of Set 8 | yongchang
# Processing Record 27 of Set 8 | cabo rojo
# Processing Record 28 of Set 8 | batagay-alyta
# Processing Record 29 of Set 8 | sakaiminato
# Processing Record 30 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 8 | morondava
# Processing Record 32 of Set 8 | bykovo
# Processing Record 33 of Set 8 | boyolangu
# Processing Record 34 of Set 8 | erhlin
# City not found. Skipping...
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | altamirano
# Processing Record 37 of Set 8 | laguna de perlas
# Processing Record 38 of Set 8 | celica
# Processing Record 39 of Set 8 | fortuna
# Processing Record 40 of Set 8 | kiruna
# Processing Record 41 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 8 | morristown
# Processing Record 43 of Set 8 | wad madani
# Processing Record 44 of Set 8 | sisimiut
# Processing Record 45 of Set 8 | margate
# Processing Record 46 of Set 8 | lakes entrance
# Processing Record 47 of Set 8 | phan thiet
# Processing Record 48 of Set 8 | brae
# Processing Record 49 of Set 8 | angoche
# Processing Record 50 of Set 8 | berbera
# Processing Record 1 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 2 of Set 9 | machiques
# Processing Record 3 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 4 of Set 9 | korla
# Processing Record 5 of Set 9 | ananindeua
# Processing Record 6 of Set 9 | yuzhno-kurilsk
# Processing Record 7 of Set 9 | krapkowice
# Processing Record 8 of Set 9 | rio verde de mato grosso
# Processing Record 9 of Set 9 | champawat
# Processing Record 10 of Set 9 | rincon
# Processing Record 11 of Set 9 | whitianga
# Processing Record 12 of Set 9 | ambulu
# Processing Record 13 of Set 9 | beringovskiy
# Processing Record 14 of Set 9 | grand gaube
# Processing Record 15 of Set 9 | cariamanga
# Processing Record 16 of Set 9 | tromso
# Processing Record 17 of Set 9 | kloulklubed
# Processing Record 18 of Set 9 | lahaina
# Processing Record 19 of Set 9 | cockburn town
# Processing Record 20 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 9 | biak
# Processing Record 22 of Set 9 | shitanjing
# Processing Record 23 of Set 9 | aklavik
# Processing Record 24 of Set 9 | chililabombwe
# Processing Record 25 of Set 9 | yabrud
# Processing Record 26 of Set 9 | baherden
# Processing Record 27 of Set 9 | faro
# Processing Record 28 of Set 9 | sangar
# Processing Record 29 of Set 9 | samarai
# Processing Record 30 of Set 9 | general roca
# Processing Record 31 of Set 9 | logan lake
# Processing Record 32 of Set 9 | puri
# Processing Record 33 of Set 9 | deputatskiy
# Processing Record 34 of Set 9 | ishigaki
# Processing Record 35 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 9 | jibuti
# Processing Record 38 of Set 9 | aksarka
# Processing Record 39 of Set 9 | kavaratti
# Processing Record 40 of Set 9 | celestun
# Processing Record 41 of Set 9 | ucluelet
# Processing Record 42 of Set 9 | hongjiang
# Processing Record 43 of Set 9 | mincivan
# Processing Record 44 of Set 9 | leshukonskoye
# Processing Record 45 of Set 9 | avera
# Processing Record 46 of Set 9 | ulagan
# Processing Record 47 of Set 9 | matata
# Processing Record 48 of Set 9 | russell
# Processing Record 49 of Set 9 | skjervoy
# Processing Record 50 of Set 9 | iwaki
# Processing Record 1 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 10 | neiafu
# Processing Record 3 of Set 10 | fukagawa
# Processing Record 4 of Set 10 | malchevskaya
# Processing Record 5 of Set 10 | san benito
# Processing Record 6 of Set 10 | gizo
# Processing Record 7 of Set 10 | ugoofaaru
# Processing Record 8 of Set 10 | vila
# Processing Record 9 of Set 10 | dayong
# Processing Record 10 of Set 10 | cartagena
# Processing Record 11 of Set 10 | richards bay
# Processing Record 12 of Set 10 | naze
# Processing Record 13 of Set 10 | shimoda
# Processing Record 14 of Set 10 | ferkessedougou
# Processing Record 15 of Set 10 | kulhudhuffushi
# Processing Record 16 of Set 10 | vaitape
# Processing Record 17 of Set 10 | eureka
# Processing Record 18 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 10 | amahai
# Processing Record 20 of Set 10 | smithers
# Processing Record 21 of Set 10 | alofi
# Processing Record 22 of Set 10 | goianesia
# Processing Record 23 of Set 10 | preobrazheniye
# Processing Record 24 of Set 10 | pinos
# Processing Record 25 of Set 10 | tatsuno
# Processing Record 26 of Set 10 | kutum
# Processing Record 27 of Set 10 | seoul
# Processing Record 28 of Set 10 | mizdah
# Processing Record 29 of Set 10 | port lincoln
# Processing Record 30 of Set 10 | oktyabrskoye
# Processing Record 31 of Set 10 | maiduguri
# Processing Record 32 of Set 10 | vestmannaeyjar
# Processing Record 33 of Set 10 | chicama
# Processing Record 34 of Set 10 | kochi
# Processing Record 35 of Set 10 | kyra
# Processing Record 36 of Set 10 | katete
# Processing Record 37 of Set 10 | sistranda
# Processing Record 38 of Set 10 | adrar
# Processing Record 39 of Set 10 | almazar
# Processing Record 40 of Set 10 | te anau
# Processing Record 41 of Set 10 | villa bruzual
# Processing Record 42 of Set 10 | caucasia
# Processing Record 43 of Set 10 | neftcala
# Processing Record 44 of Set 10 | burglengenfeld
# Processing Record 45 of Set 10 | sao joao da barra
# Processing Record 46 of Set 10 | henties bay
# Processing Record 47 of Set 10 | dekar
# Processing Record 48 of Set 10 | khanu woralaksaburi
# Processing Record 49 of Set 10 | vicente guerrero
# Processing Record 50 of Set 10 | wadi musa
# Processing Record 1 of Set 11 | ostrovnoy
# Processing Record 2 of Set 11 | inhambane
# Processing Record 3 of Set 11 | bubaque
# Processing Record 4 of Set 11 | fairbanks
# Processing Record 5 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 11 | sao joao do paraiso
# Processing Record 8 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 9 of Set 11 | morant bay
# Processing Record 10 of Set 11 | cairns
# Processing Record 11 of Set 11 | watsa
# Processing Record 12 of Set 11 | chimore
# Processing Record 13 of Set 11 | kaka
# Processing Record 14 of Set 11 | mildura
# Processing Record 15 of Set 11 | yashkino
# Processing Record 16 of Set 11 | sirnak
# Processing Record 17 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 18 of Set 11 | cayenne
# Processing Record 19 of Set 11 | puerto baquerizo moreno
# Processing Record 20 of Set 11 | anahuac
# Processing Record 21 of Set 11 | rundu
# Processing Record 22 of Set 11 | tibati
# Processing Record 23 of Set 11 | acarau
# Processing Record 24 of Set 11 | abay
# Processing Record 25 of Set 11 | port moresby
# Processing Record 26 of Set 11 | ha tinh
# Processing Record 27 of Set 11 | uarini
# Processing Record 28 of Set 11 | tombouctou
# Processing Record 29 of Set 11 | de-kastri
# Processing Record 30 of Set 11 | ofaqim
# Processing Record 31 of Set 11 | bartica
# Processing Record 32 of Set 11 | alice springs
# Processing Record 33 of Set 11 | dalaba
# Processing Record 34 of Set 11 | alto araguaia
# Processing Record 35 of Set 11 | makokou
# Processing Record 36 of Set 11 | hukuntsi
# Processing Record 37 of Set 11 | puro
# Processing Record 38 of Set 11 | zhigansk
# Processing Record 39 of Set 11 | kibondo
# Processing Record 40 of Set 11 | usinsk
# Processing Record 41 of Set 11 | yaan
# Processing Record 42 of Set 11 | harper
# Processing Record 43 of Set 11 | pareora
# Processing Record 44 of Set 11 | flinders
# Processing Record 45 of Set 11 | dukat
# Processing Record 46 of Set 11 | andenes
# Processing Record 47 of Set 11 | pedra azul
# Processing Record 48 of Set 11 | mabaruma
# Processing Record 49 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 11 | poshekhonye
# Processing Record 1 of Set 12 | iberia
# Processing Record 2 of Set 12 | nauta
# Processing Record 3 of Set 12 | payyannur
# Processing Record 4 of Set 12 | pittsburg
# Processing Record 5 of Set 12 | adre
# Processing Record 6 of Set 12 | gujar khan
# Processing Record 7 of Set 12 | semey
# Processing Record 8 of Set 12 | cumberland
# Processing Record 9 of Set 12 | pascagoula
# Processing Record 10 of Set 12 | inongo
# Processing Record 11 of Set 12 | touros
# Processing Record 12 of Set 12 | prata
# Processing Record 13 of Set 12 | genhe
# Processing Record 14 of Set 12 | cerrito
# Processing Record 15 of Set 12 | jumla
# Processing Record 16 of Set 12 | sao cristovao
# Processing Record 17 of Set 12 | harbour breton
# Processing Record 18 of Set 12 | basco
# Processing Record 19 of Set 12 | launceston
# Processing Record 20 of Set 12 | eyl
# Processing Record 21 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 22 of Set 12 | pilis
# Processing Record 23 of Set 12 | berdigestyakh
# Processing Record 24 of Set 12 | aleksandrov gay
# Processing Record 25 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 26 of Set 12 | beian
# Processing Record 27 of Set 12 | alim
# Processing Record 28 of Set 12 | kamenka
# Processing Record 29 of Set 12 | juxtlahuaca
# Processing Record 30 of Set 12 | tomatlan
# Processing Record 31 of Set 12 | tulsipur
# Processing Record 32 of Set 12 | saint-tite
# Processing Record 33 of Set 12 | nurota
# Processing Record 34 of Set 12 | batagay
# Processing Record 35 of Set 12 | petauke
# Processing Record 36 of Set 12 | qaqortoq
# Processing Record 37 of Set 12 | sabha
# Processing Record 38 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 12 | bjelovar
# Processing Record 40 of Set 12 | almirante tamandare
# Processing Record 41 of Set 12 | sao raimundo nonato
# Processing Record 42 of Set 12 | litovko
# Processing Record 43 of Set 12 | marsabit
# Processing Record 44 of Set 12 | kudahuvadhoo
# Processing Record 45 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 46 of Set 12 | sungaipenuh
# Processing Record 47 of Set 12 | ushtobe
# Processing Record 48 of Set 12 | baruun-urt
# Processing Record 49 of Set 12 | makakilo city
# Processing Record 50 of Set 12 | cooma
# Processing Record 1 of Set 13 | kendari
# Processing Record 2 of Set 13 | pasni
# Processing Record 3 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 4 of Set 13 | devils lake
# Processing Record 5 of Set 13 | otane
# Processing Record 6 of Set 13 | port augusta
# Processing Record 7 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 8 of Set 13 | decatur
# Processing Record 9 of Set 13 | simnas
# Processing Record 10 of Set 13 | kaeo
# Processing Record 11 of Set 13 | portland
# Processing Record 12 of Set 13 | banjar
# Processing Record 13 of Set 13 | dillon
# Processing Record 14 of Set 13 | ranghulu
# Processing Record 15 of Set 13 | buchanan
# Processing Record 16 of Set 13 | mtsamboro
# Processing Record 17 of Set 13 | severnoye
# Processing Record 18 of Set 13 | waipawa
# Processing Record 19 of Set 13 | helong
# Processing Record 20 of Set 13 | kailua
# Processing Record 21 of Set 13 | haines junction
# Processing Record 22 of Set 13 | pervomayskoye
# Processing Record 23 of Set 13 | abohar
# Processing Record 24 of Set 13 | vilhena
# Processing Record 25 of Set 13 | tommot
# Processing Record 26 of Set 13 | mantua
# Processing Record 27 of Set 13 | umm ruwabah
# City not found. Skipping...
# Processing Record 28 of Set 13 | andros town
# Processing Record 29 of Set 13 | antalaha
# Processing Record 30 of Set 13 | pucara
# Processing Record 31 of Set 13 | dingle
# Processing Record 32 of Set 13 | pandamatenga
# Processing Record 33 of Set 13 | moyale
# Processing Record 34 of Set 13 | dudinka
# Processing Record 35 of Set 13 | aripuana
# Processing Record 36 of Set 13 | asau
# Processing Record 37 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 38 of Set 13 | salamiyah
# Processing Record 39 of Set 13 | choya
# Processing Record 40 of Set 13 | amapa
# Processing Record 41 of Set 13 | lorengau
# Processing Record 42 of Set 13 | songea
# Processing Record 43 of Set 13 | vanimo
# Processing Record 44 of Set 13 | nieuw nickerie
# Processing Record 45 of Set 13 | cuamba
# Processing Record 46 of Set 13 | tarko-sale
# Processing Record 47 of Set 13 | mogochin
# City not found. Skipping...
# Processing Record 48 of Set 13 | kathu
# Processing Record 49 of Set 13 | marrakesh
# Processing Record 50 of Set 13 | mecca
# Processing Record 1 of Set 14 | hay river
# Processing Record 2 of Set 14 | namatanai
# Processing Record 3 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 14 | burnie
# Processing Record 5 of Set 14 | ilhabela
# Processing Record 6 of Set 14 | tatarbunary
# Processing Record 7 of Set 14 | mhango
# Processing Record 8 of Set 14 | fomboni
# Processing Record 9 of Set 14 | tutoia
# Processing Record 10 of Set 14 | paita
# Processing Record 11 of Set 14 | qeshm
# Processing Record 12 of Set 14 | magdiwang
# Processing Record 13 of Set 14 | vila franca do campo
# Processing Record 14 of Set 14 | parlakimidi
# Processing Record 15 of Set 14 | codrington
# Processing Record 16 of Set 14 | kupang
# Processing Record 17 of Set 14 | lasa
# Processing Record 18 of Set 14 | san andres
# Processing Record 19 of Set 14 | wadowice
# Processing Record 20 of Set 14 | marawi
# Processing Record 21 of Set 14 | champerico
# Processing Record 22 of Set 14 | carauari
# Processing Record 23 of Set 14 | bad liebenwerda
# Processing Record 24 of Set 14 | neuquen
# Processing Record 25 of Set 14 | hamilton
# Processing Record 26 of Set 14 | tambopata
# Processing Record 27 of Set 14 | nuuk
# Processing Record 28 of Set 14 | adria
# Processing Record 29 of Set 14 | dera bugti
# Processing Record 30 of Set 14 | andra
# Processing Record 31 of Set 14 | porto novo
# Processing Record 32 of Set 14 | carnduff
# Processing Record 33 of Set 14 | sobolevo
# Processing Record 34 of Set 14 | baykit
# Processing Record 35 of Set 14 | ust-nera
# Processing Record 36 of Set 14 | ulaangom
# Processing Record 37 of Set 14 | batsfjord
# Processing Record 38 of Set 14 | mackenzie
# Processing Record 39 of Set 14 | inuvik
# Processing Record 40 of Set 14 | zaysan
# Processing Record 41 of Set 14 | aron
# Processing Record 42 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 43 of Set 14 | baie-comeau
# Processing Record 44 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 14 | bunia
# Processing Record 46 of Set 14 | tynda
# Processing Record 47 of Set 14 | raudeberg
# Processing Record 48 of Set 14 | atocha
# Processing Record 49 of Set 14 | erzin
# Processing Record 50 of Set 14 | nishihara
# Processing Record 1 of Set 15 | sur
# Processing Record 2 of Set 15 | pilao arcado
# City not found. Skipping...
# Processing Record 3 of Set 15 | san quintin
# Processing Record 4 of Set 15 | muborak
# Processing Record 5 of Set 15 | coquimbo
# Processing Record 6 of Set 15 | luganville
# Processing Record 7 of Set 15 | tefe
# Processing Record 8 of Set 15 | yuzhou
# Processing Record 9 of Set 15 | yeppoon
# Processing Record 10 of Set 15 | shenjiamen
# Processing Record 11 of Set 15 | shirochanka
# Processing Record 12 of Set 15 | anjozorobe
# Processing Record 13 of Set 15 | ylojarvi
# Processing Record 14 of Set 15 | itaituba
# Processing Record 15 of Set 15 | murgab
# Processing Record 16 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 17 of Set 15 | fort frances
# Processing Record 18 of Set 15 | akdepe
# Processing Record 19 of Set 15 | oktyabrskiy
# Processing Record 20 of Set 15 | zlynka
# Processing Record 21 of Set 15 | kingaroy
# Processing Record 22 of Set 15 | prince rupert
# Processing Record 23 of Set 15 | dutlwe
# Processing Record 24 of Set 15 | ayr
# Processing Record 25 of Set 15 | saint-augustin
# Processing Record 26 of Set 15 | rio gallegos
# Processing Record 27 of Set 15 | sinnamary
# Processing Record 28 of Set 15 | butte
# Processing Record 29 of Set 15 | aqtobe
# Processing Record 30 of Set 15 | itaqui
# Processing Record 31 of Set 15 | panjab
# Processing Record 32 of Set 15 | mount gambier
# Processing Record 33 of Set 15 | husavik
# Processing Record 34 of Set 15 | krasnoselkup
# Processing Record 35 of Set 15 | iskateley
# Processing Record 36 of Set 15 | turukhansk
# Processing Record 37 of Set 15 | herat
# Processing Record 38 of Set 15 | daru
# Processing Record 39 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 40 of Set 15 | chinu
# Processing Record 41 of Set 15 | college
# Processing Record 42 of Set 15 | vung tau
# Processing Record 43 of Set 15 | ginda
# Processing Record 44 of Set 15 | le pont-de-claix
# Processing Record 45 of Set 15 | walvis bay
# Processing Record 46 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 15 | buenos aires
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 679

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0        Barrow  71.2906 -156.7887     -7.58          light snow        84
# 1        Juwana  -6.7150  111.1514     75.65     overcast clouds        90
# 2    Sao Filipe  14.8961  -24.4956     72.81       broken clouds        70
# 3      Bengkulu  -3.8004  102.2655     76.69       moderate rain        87
# 4        Shingu  33.7333  135.9833     36.77     overcast clouds        65
# 5  Norman Wells  65.2820 -126.8329    -41.76                mist        66
# 6      Hermanus -34.4187   19.2345     71.80           clear sky        64
# 7      Rosarito  32.3333 -117.0333     58.24       broken clouds        36
# 8    Butaritari   3.0707  172.7902     80.20          light rain        79
# 9        Faanui -16.4833 -151.7500     81.30    scattered clouds        75
#
#    Cloudiness  Wind Speed Country
# 0           0       12.66      US
# 1         100        5.64      ID
# 2          75       13.56      CV
# 3          97        6.64      ID
# 4         100        5.93      JP
# 5          20        3.44      CA
# 6           0        9.71      ZA
# 7          56        3.94      MX
# 8         100       19.55      KI
# 9          26       19.71      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.2906 -156.7887     -7.58        84           0
# 1        Juwana      ID  -6.7150  111.1514     75.65        90         100
# 2    Sao Filipe      CV  14.8961  -24.4956     72.81        70          75
# 3      Bengkulu      ID  -3.8004  102.2655     76.69        87          97
# 4        Shingu      JP  33.7333  135.9833     36.77        65         100
# 5  Norman Wells      CA  65.2820 -126.8329    -41.76        66          20
# 6      Hermanus      ZA -34.4187   19.2345     71.80        64           0
# 7      Rosarito      MX  32.3333 -117.0333     58.24        36          56
# 8    Butaritari      KI   3.0707  172.7902     80.20        79         100
# 9        Faanui      PF -16.4833 -151.7500     81.30        75          26
#
#    Wind Speed Current Description
# 0       12.66          light snow
# 1        5.64     overcast clouds
# 2       13.56       broken clouds
# 3        6.64       moderate rain
# 4        5.93     overcast clouds
# 5        3.44                mist
# 6        9.71           clear sky
# 7        3.94       broken clouds
# 8       19.55          light rain
# 9       19.71    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = (r'C:\Users\Upt0w\OneDrive\Desktop\Data Bootcamp Class Folder\Github Repositories\World_Weather_Analysis\Weather_Database/WeatherPy_Database.csv')

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
